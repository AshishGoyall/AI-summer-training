# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree,datasets,metrics,model_selection

data = datasets.load_iris()

X = data.data
Y = data.target
print(X.shape,Y.shape)
X_train,X_test,Y_train,Y_test = model_selection.train_test_split(X,Y,test_size=0.4,random_state=0)

tree_model = tree.DecisionTreeClassifier(criterion = 'entropy',max_depth=None)

tree_model.fit(X_train,Y_train)

ypredtest = tree_model.predict(X_test)

ypredTest = tree_model.predict(X_test)
print(metrics.accuracy_score(ypredtest,ypredTest))

acctest = metrics.accuracy_score(Y_test,ypredTest)
accTest = metrics.accuracy_score(Y_test,ypredtest)
print("Testing Accuracy : ",accTest)
print("Testing Accuracy :",acctest)
# Out:
# (150, 4) (150,)
# 1.0
# Testing Accuracy :  0.95
# Testing Accuracy : 0.95

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
tree_model.feature_importances_ #this attribute holding the value for the feature omn thre basis of their importance
#
# Out:
# array([0.        , 0.01939657, 0.31999645, 0.66060698])

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
plt.figure(1,(4,4))
tree.plot_tree(tree_model,filled=True,rounded = True )
# Out:
# [Text(0.4, 0.9, 'x[3] <= 0.75\nentropy = 1.578\nsamples = 90\nvalue = [34, 27, 29]'),
#  Text(0.2, 0.7, 'entropy = 0.0\nsamples = 34\nvalue = [34, 0, 0]'),
#  Text(0.6, 0.7, 'x[2] <= 5.05\nentropy = 0.999\nsamples = 56\nvalue = [0, 27, 29]'),
#  Text(0.4, 0.5, 'x[3] <= 1.75\nentropy = 0.362\nsamples = 29\nvalue = [0, 27, 2]'),
#  Text(0.2, 0.3, 'entropy = 0.0\nsamples = 26\nvalue = [0, 26, 0]'),
#  Text(0.6, 0.3, 'x[1] <= 3.1\nentropy = 0.918\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.4, 0.1, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8, 0.5, 'entropy = 0.0\nsamples = 27\nvalue = [0, 0, 27]')]

# %%
# mounting the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
data=pd.read_csv("/content/diabetes.csv")
print(data.shape)
print(data.head())
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# split the data into train and test
r = 0.3
x_train, x_test, y_train, y_test = model_selection.train_test_split(x, y, test_size=r, random_state=5)

# create decision tree
tree_model = tree.DecisionTreeClassifier(criterion='entropy', max_depth=None)

# train the model
tree_model = tree_model.fit(x_train, y_train)

# predict the train data for training accuracy
y_pred_train = tree_model.predict(x_train)

# predict the test data for testing accuracy
y_pred_test = tree_model.predict(x_test)

# calculate testing and training accuracy
accTrain = metrics.accuracy_score(y_pred_train, y_train)
accTest = metrics.accuracy_score(y_pred_test, y_test)

print("Training Accuracy:", accTrain)
print("Testing Accuracy:", accTest)
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.007518796992481203

# %%
plt.figure(figsize=(20,10))
tree.plot_tree(tree_model, filled=True, rounded=True)
plt.savefig('tree.png')
plt.show()

# %%
# !unzip "/content/orl_face.zip"
# Out:
# Archive:  /content/orl_face.zip
#    creating: orl_face/
#   inflating: orl_face/.DS_Store
#    creating: __MACOSX/
#    creating: __MACOSX/orl_face/
#   inflating: __MACOSX/orl_face/._.DS_Store
#    creating: orl_face/u1/
#   inflating: orl_face/u1/1.png
#    creating: __MACOSX/orl_face/u1/
#   inflating: __MACOSX/orl_face/u1/._1.png
#   inflating: orl_face/u1/10.png
#   inflating: orl_face/u1/2.png
#   inflating: orl_face/u1/3.png
#   inflating: orl_face/u1/4.png
#   inflating: orl_face/u1/5.png
#   inflating: orl_face/u1/6.png
#   inflating: orl_face/u1/7.png
#   inflating: orl_face/u1/8.png
#   inflating: orl_face/u1/9.png
#    creating: orl_face/u10/
#   inflating: orl_face/u10/1.png
#   inflating: orl_face/u10/10.png
#   inflating: orl_face/u10/2.png
#   inflating: orl_face/u10/3.png
#   inflating: orl_face/u10/4.png
#   inflating: orl_face/u10/5.png
#   inflating: orl_face/u10/6.png
#   inflating: orl_face/u10/7.png
#   inflating: orl_face/u10/8.png
#   inflating: orl_face/u10/9.png
#    creating: orl_face/u11/
#   inflating: orl_face/u11/1.png
#   inflating: orl_face/u11/10.png
#   inflating: orl_face/u11/2.png
#   inflating: orl_face/u11/3.png
#   inflating: orl_face/u11/4.png
#   inflating: orl_face/u11/5.png
#   inflating: orl_face/u11/6.png
#   inflating: orl_face/u11/7.png
#   inflating: orl_face/u11/8.png
#   inflating: orl_face/u11/9.png
#    creating: orl_face/u12/
#   inflating: orl_face/u12/1.png
#   inflating: orl_face/u12/10.png
#   inflating: orl_face/u12/2.png
#   inflating: orl_face/u12/3.png
#   inflating: orl_face/u12/4.png
#   inflating: orl_face/u12/5.png
#   inflating: orl_face/u12/6.png
#   inflating: orl_face/u12/7.png
#   inflating: orl_face/u12/8.png
#   inflating: orl_face/u12/9.png
#    creating: orl_face/u13/
#   inflating: orl_face/u13/1.png
#   inflating: orl_face/u13/10.png
#   inflating: orl_face/u13/2.png
#   inflating: orl_face/u13/3.png
#   inflating: orl_face/u13/4.png
#   inflating: orl_face/u13/5.png
#   inflating: orl_face/u13/6.png
#   inflating: orl_face/u13/7.png
#   inflating: orl_face/u13/8.png
#   inflating: orl_face/u13/9.png
#    creating: orl_face/u14/
#   inflating: orl_face/u14/1.png
#   inflating: orl_face/u14/10.png
#   inflating: orl_face/u14/2.png
#   inflating: orl_face/u14/3.png
#   inflating: orl_face/u14/4.png
#   inflating: orl_face/u14/5.png
#   inflating: orl_face/u14/6.png
#   inflating: orl_face/u14/7.png
#   inflating: orl_face/u14/8.png
#   inflating: orl_face/u14/9.png
#    creating: orl_face/u15/
#   inflating: orl_face/u15/1.png
#   inflating: orl_face/u15/10.png
#   inflating: orl_face/u15/2.png
#   inflating: orl_face/u15/3.png
#   inflating: orl_face/u15/4.png
#   inflating: orl_face/u15/5.png
#   inflating: orl_face/u15/6.png
#   inflating: orl_face/u15/7.png
#   inflating: orl_face/u15/8.png
#   inflating: orl_face/u15/9.png
#    creating: orl_face/u16/
#   inflating: orl_face/u16/1.png
#   inflating: orl_face/u16/10.png
#   inflating: orl_face/u16/2.png
#   inflating: orl_face/u16/3.png
#   inflating: orl_face/u16/4.png
#   inflating: orl_face/u16/5.png
#   inflating: orl_face/u16/6.png
#   inflating: orl_face/u16/7.png
#   inflating: orl_face/u16/8.png
#   inflating: orl_face/u16/9.png
#    creating: orl_face/u17/
#   inflating: orl_face/u17/1.png
#   inflating: orl_face/u17/10.png
#   inflating: orl_face/u17/2.png
#   inflating: orl_face/u17/3.png
#   inflating: orl_face/u17/4.png
#   inflating: orl_face/u17/5.png
#   inflating: orl_face/u17/6.png
#   inflating: orl_face/u17/7.png
#   inflating: orl_face/u17/8.png
#   inflating: orl_face/u17/9.png
#    creating: orl_face/u18/
#   inflating: orl_face/u18/1.png
#   inflating: orl_face/u18/10.png
#   inflating: orl_face/u18/2.png
#   inflating: orl_face/u18/3.png
#   inflating: orl_face/u18/4.png
#   inflating: orl_face/u18/5.png
#   inflating: orl_face/u18/6.png
#   inflating: orl_face/u18/7.png
#   inflating: orl_face/u18/8.png
#   inflating: orl_face/u18/9.png
#    creating: orl_face/u19/
#   inflating: orl_face/u19/1.png
#   inflating: orl_face/u19/10.png
#   inflating: orl_face/u19/2.png
#   inflating: orl_face/u19/3.png
#   inflating: orl_face/u19/4.png
#   inflating: orl_face/u19/5.png
#   inflating: orl_face/u19/6.png
#   inflating: orl_face/u19/7.png
#   inflating: orl_face/u19/8.png
#   inflating: orl_face/u19/9.png
#    creating: orl_face/u2/
#   inflating: orl_face/u2/1.png
#   inflating: orl_face/u2/10.png
#   inflating: orl_face/u2/2.png
#   inflating: orl_face/u2/3.png
#   inflating: orl_face/u2/4.png
#   inflating: orl_face/u2/5.png
#   inflating: orl_face/u2/6.png
#   inflating: orl_face/u2/7.png
#   inflating: orl_face/u2/8.png
#   inflating: orl_face/u2/9.png
#    creating: orl_face/u20/
#   inflating: orl_face/u20/1.png
#   inflating: orl_face/u20/10.png
#   inflating: orl_face/u20/2.png
#   inflating: orl_face/u20/3.png
#   inflating: orl_face/u20/4.png
#   inflating: orl_face/u20/5.png
#   inflating: orl_face/u20/6.png
#   inflating: orl_face/u20/7.png
#   inflating: orl_face/u20/8.png
#   inflating: orl_face/u20/9.png
#    creating: orl_face/u21/
#   inflating: orl_face/u21/1.png
#   inflating: orl_face/u21/10.png
#   inflating: orl_face/u21/2.png
#   inflating: orl_face/u21/3.png
#   inflating: orl_face/u21/4.png
#   inflating: orl_face/u21/5.png
#   inflating: orl_face/u21/6.png
#   inflating: orl_face/u21/7.png
#   inflating: orl_face/u21/8.png
#   inflating: orl_face/u21/9.png
#    creating: orl_face/u22/
#   inflating: orl_face/u22/1.png
#   inflating: orl_face/u22/10.png
#   inflating: orl_face/u22/2.png
#   inflating: orl_face/u22/3.png
#   inflating: orl_face/u22/4.png
#   inflating: orl_face/u22/5.png
#   inflating: orl_face/u22/6.png
#   inflating: orl_face/u22/7.png
#   inflating: orl_face/u22/8.png
#   inflating: orl_face/u22/9.png
#    creating: orl_face/u23/
#   inflating: orl_face/u23/1.png
#   inflating: orl_face/u23/10.png
#   inflating: orl_face/u23/2.png
#   inflating: orl_face/u23/3.png
#   inflating: orl_face/u23/4.png
#   inflating: orl_face/u23/5.png
#   inflating: orl_face/u23/6.png
#   inflating: orl_face/u23/7.png
#   inflating: orl_face/u23/8.png
#   inflating: orl_face/u23/9.png
#    creating: orl_face/u24/
#   inflating: orl_face/u24/1.png
#   inflating: orl_face/u24/10.png
#   inflating: orl_face/u24/2.png
#   inflating: orl_face/u24/3.png
#   inflating: orl_face/u24/4.png
#   inflating: orl_face/u24/5.png
#   inflating: orl_face/u24/6.png
#   inflating: orl_face/u24/7.png
#   inflating: orl_face/u24/8.png
#   inflating: orl_face/u24/9.png
#    creating: orl_face/u25/
#   inflating: orl_face/u25/1.png
#   inflating: orl_face/u25/10.png
#   inflating: orl_face/u25/2.png
#   inflating: orl_face/u25/3.png
#   inflating: orl_face/u25/4.png
#   inflating: orl_face/u25/5.png
#   inflating: orl_face/u25/6.png
#   inflating: orl_face/u25/7.png
#   inflating: orl_face/u25/8.png
#   inflating: orl_face/u25/9.png
#    creating: orl_face/u26/
#   inflating: orl_face/u26/1.png
#   inflating: orl_face/u26/10.png
#   inflating: orl_face/u26/2.png
#   inflating: orl_face/u26/3.png
#   inflating: orl_face/u26/4.png
#   inflating: orl_face/u26/5.png
#   inflating: orl_face/u26/6.png
#   inflating: orl_face/u26/7.png
#   inflating: orl_face/u26/8.png
#   inflating: orl_face/u26/9.png
#    creating: orl_face/u27/
#   inflating: orl_face/u27/1.png
#   inflating: orl_face/u27/10.png
#   inflating: orl_face/u27/2.png
#   inflating: orl_face/u27/3.png
#   inflating: orl_face/u27/4.png
#   inflating: orl_face/u27/5.png
#   inflating: orl_face/u27/6.png
#   inflating: orl_face/u27/7.png
#   inflating: orl_face/u27/8.png
#   inflating: orl_face/u27/9.png
#    creating: orl_face/u28/
#   inflating: orl_face/u28/1.png
#   inflating: orl_face/u28/10.png
#   inflating: orl_face/u28/2.png
#   inflating: orl_face/u28/3.png
#   inflating: orl_face/u28/4.png
#   inflating: orl_face/u28/5.png
#   inflating: orl_face/u28/6.png
#   inflating: orl_face/u28/7.png
#   inflating: orl_face/u28/8.png
#   inflating: orl_face/u28/9.png
#    creating: orl_face/u29/
#   inflating: orl_face/u29/1.png
#   inflating: orl_face/u29/10.png
#   inflating: orl_face/u29/2.png
#   inflating: orl_face/u29/3.png
#   inflating: orl_face/u29/4.png
#   inflating: orl_face/u29/5.png
#   inflating: orl_face/u29/6.png
#   inflating: orl_face/u29/7.png
#   inflating: orl_face/u29/8.png
#   inflating: orl_face/u29/9.png
#    creating: orl_face/u3/
#   inflating: orl_face/u3/1.png
#   inflating: orl_face/u3/10.png
#   inflating: orl_face/u3/2.png
#   inflating: orl_face/u3/3.png
#   inflating: orl_face/u3/4.png
#   inflating: orl_face/u3/5.png
#   inflating: orl_face/u3/6.png
#   inflating: orl_face/u3/7.png
#   inflating: orl_face/u3/8.png
#   inflating: orl_face/u3/9.png
#    creating: orl_face/u30/
#   inflating: orl_face/u30/1.png
#   inflating: orl_face/u30/10.png
#   inflating: orl_face/u30/2.png
#   inflating: orl_face/u30/3.png
#   inflating: orl_face/u30/4.png
#   inflating: orl_face/u30/5.png
#   inflating: orl_face/u30/6.png
#   inflating: orl_face/u30/7.png
#   inflating: orl_face/u30/8.png
#   inflating: orl_face/u30/9.png
#    creating: orl_face/u31/
#   inflating: orl_face/u31/1.png
#   inflating: orl_face/u31/10.png
#   inflating: orl_face/u31/2.png
#   inflating: orl_face/u31/3.png
#   inflating: orl_face/u31/4.png
#   inflating: orl_face/u31/5.png
#   inflating: orl_face/u31/6.png
#   inflating: orl_face/u31/7.png
#   inflating: orl_face/u31/8.png
#   inflating: orl_face/u31/9.png
#    creating: orl_face/u32/
#   inflating: orl_face/u32/1.png
#   inflating: orl_face/u32/10.png
#   inflating: orl_face/u32/2.png
#   inflating: orl_face/u32/3.png
#   inflating: orl_face/u32/4.png
#   inflating: orl_face/u32/5.png
#   inflating: orl_face/u32/6.png
#   inflating: orl_face/u32/7.png
#   inflating: orl_face/u32/8.png
#   inflating: orl_face/u32/9.png
#    creating: orl_face/u33/
#   inflating: orl_face/u33/1.png
#   inflating: orl_face/u33/10.png
#   inflating: orl_face/u33/2.png
#   inflating: orl_face/u33/3.png
#   inflating: orl_face/u33/4.png
#   inflating: orl_face/u33/5.png
#   inflating: orl_face/u33/6.png
#   inflating: orl_face/u33/7.png
#   inflating: orl_face/u33/8.png
#   inflating: orl_face/u33/9.png
#    creating: orl_face/u34/
#   inflating: orl_face/u34/1.png
#   inflating: orl_face/u34/10.png
#   inflating: orl_face/u34/2.png
#   inflating: orl_face/u34/3.png
#   inflating: orl_face/u34/4.png
#   inflating: orl_face/u34/5.png
#   inflating: orl_face/u34/6.png
#   inflating: orl_face/u34/7.png
#   inflating: orl_face/u34/8.png
#   inflating: orl_face/u34/9.png
#    creating: orl_face/u35/
#   inflating: orl_face/u35/1.png
#   inflating: orl_face/u35/10.png
#   inflating: orl_face/u35/2.png
#   inflating: orl_face/u35/3.png
#   inflating: orl_face/u35/4.png
#   inflating: orl_face/u35/5.png
#   inflating: orl_face/u35/6.png
#   inflating: orl_face/u35/7.png
#   inflating: orl_face/u35/8.png
#   inflating: orl_face/u35/9.png
#    creating: orl_face/u36/
#   inflating: orl_face/u36/1.png
#   inflating: orl_face/u36/10.png
#   inflating: orl_face/u36/2.png
#   inflating: orl_face/u36/3.png
#   inflating: orl_face/u36/4.png
#   inflating: orl_face/u36/5.png
#   inflating: orl_face/u36/6.png
#   inflating: orl_face/u36/7.png
#   inflating: orl_face/u36/8.png
#   inflating: orl_face/u36/9.png
#    creating: orl_face/u37/
#   inflating: orl_face/u37/1.png
#   inflating: orl_face/u37/10.png
#   inflating: orl_face/u37/2.png
#   inflating: orl_face/u37/3.png
#   inflating: orl_face/u37/4.png
#   inflating: orl_face/u37/5.png
#   inflating: orl_face/u37/6.png
#   inflating: orl_face/u37/7.png
#   inflating: orl_face/u37/8.png
#   inflating: orl_face/u37/9.png
#    creating: orl_face/u38/
#   inflating: orl_face/u38/1.png
#   inflating: orl_face/u38/10.png
#   inflating: orl_face/u38/2.png
#   inflating: orl_face/u38/3.png
#   inflating: orl_face/u38/4.png
#   inflating: orl_face/u38/5.png
#   inflating: orl_face/u38/6.png
#   inflating: orl_face/u38/7.png
#   inflating: orl_face/u38/8.png
#   inflating: orl_face/u38/9.png
#    creating: orl_face/u39/
#   inflating: orl_face/u39/1.png
#   inflating: orl_face/u39/10.png
#   inflating: orl_face/u39/2.png
#   inflating: orl_face/u39/3.png
#   inflating: orl_face/u39/4.png
#   inflating: orl_face/u39/5.png
#   inflating: orl_face/u39/6.png
#   inflating: orl_face/u39/7.png
#   inflating: orl_face/u39/8.png
#   inflating: orl_face/u39/9.png
#    creating: orl_face/u4/
#   inflating: orl_face/u4/1.png
#   inflating: orl_face/u4/10.png
#   inflating: orl_face/u4/2.png
#   inflating: orl_face/u4/3.png
#   inflating: orl_face/u4/4.png
#   inflating: orl_face/u4/5.png
#   inflating: orl_face/u4/6.png
#   inflating: orl_face/u4/7.png
#   inflating: orl_face/u4/8.png
#   inflating: orl_face/u4/9.png
#    creating: orl_face/u40/
#   inflating: orl_face/u40/1.png
#   inflating: orl_face/u40/10.png
#   inflating: orl_face/u40/2.png
#   inflating: orl_face/u40/3.png
#   inflating: orl_face/u40/4.png
#   inflating: orl_face/u40/5.png
#   inflating: orl_face/u40/6.png
#   inflating: orl_face/u40/7.png
#   inflating: orl_face/u40/8.png
#   inflating: orl_face/u40/9.png
#    creating: orl_face/u5/
#   inflating: orl_face/u5/1.png
#   inflating: orl_face/u5/10.png
#   inflating: orl_face/u5/2.png
#   inflating: orl_face/u5/3.png
#   inflating: orl_face/u5/4.png
#   inflating: orl_face/u5/5.png
#   inflating: orl_face/u5/6.png
#   inflating: orl_face/u5/7.png
#   inflating: orl_face/u5/8.png
#   inflating: orl_face/u5/9.png
#    creating: orl_face/u6/
#   inflating: orl_face/u6/1.png
#   inflating: orl_face/u6/10.png
#   inflating: orl_face/u6/2.png
#   inflating: orl_face/u6/3.png
#   inflating: orl_face/u6/4.png
#   inflating: orl_face/u6/5.png
#   inflating: orl_face/u6/6.png
#   inflating: orl_face/u6/7.png
#   inflating: orl_face/u6/8.png
#   inflating: orl_face/u6/9.png
#    creating: orl_face/u7/
#   inflating: orl_face/u7/1.png
#   inflating: orl_face/u7/10.png
#   inflating: orl_face/u7/2.png
#   inflating: orl_face/u7/3.png
#   inflating: orl_face/u7/4.png
#   inflating: orl_face/u7/5.png
#   inflating: orl_face/u7/6.png
#   inflating: orl_face/u7/7.png
#   inflating: orl_face/u7/8.png
#   inflating: orl_face/u7/9.png
#    creating: orl_face/u8/
#   inflating: orl_face/u8/1.png
#   inflating: orl_face/u8/10.png
#   inflating: orl_face/u8/2.png
#   inflating: orl_face/u8/3.png
#   inflating: orl_face/u8/4.png
#   inflating: orl_face/u8/5.png
#   inflating: orl_face/u8/6.png
#   inflating: orl_face/u8/7.png
#   inflating: orl_face/u8/8.png
#   inflating: orl_face/u8/9.png
#    creating: orl_face/u9/
#   inflating: orl_face/u9/1.png
#   inflating: orl_face/u9/10.png
#   inflating: orl_face/u9/2.png
#   inflating: orl_face/u9/3.png
#   inflating: orl_face/u9/4.png
#   inflating: orl_face/u9/5.png
#   inflating: orl_face/u9/6.png
#   inflating: orl_face/u9/7.png
#   inflating: orl_face/u9/8.png
#   inflating: orl_face/u9/9.png

# %%
import matplotlib.image as mimg
import matplotlib.pyplot as plt

# access any single image
usr_name = 24
samp_no = 6

path = "/content/orl_face/u%d/%d.png"%(usr_name,samp_no)

# read the image
im = mimg.imread(path)

print(type(im))
print(im.shape)

# display the image
plt.imshow(im,cmap='gray')
plt.axis('off')
# Out:
# <class 'numpy.ndarray'>
# (112, 92)
# (-0.5, 91.5, 111.5, -0.5)

# %%
# convert the 2D-data of image into 1-D features
feat = im.reshape(1,-1)# shift all the values of the image
#into the columns in one single row
print(im.shape)
print(feat.shape)
print("range:",im.min(),'-',im.max())
# Out:
# (112, 92)
# (1, 10304)
# range: 0.05490196 - 0.89411765

# %%
# logic to access all the samples of all
# the users
tot_samples = 400
data = np.zeros((tot_samples,im.shape[0]*im.shape[1]))
label = np.zeros((tot_samples))
images = np.zeros((tot_samples,im.shape[0],im.shape[1]))
indx=-1
for i in range(1,41,1): # to traverse users
  for j in range(1,11,1): # to traverse samples
    indx = indx+1
    # access any single image
    usr_name = i
    samp_no = j
    path = "/content/orl_face/u%d/%d.png"%(usr_name,samp_no)
    # read the image
    im = mimg.imread(path)
    feat = im.reshape(1,-1)
    data[indx,:]=feat
    label[indx]=i
    images[indx,:,:]=im
    print("user num ",i,'samp no',j,'processed...')
# Out:
# user num  1 samp no 1 processed...
# user num  1 samp no 2 processed...
# user num  1 samp no 3 processed...
# user num  1 samp no 4 processed...
# user num  1 samp no 5 processed...
# user num  1 samp no 6 processed...
# user num  1 samp no 7 processed...
# user num  1 samp no 8 processed...
# user num  1 samp no 9 processed...
# user num  1 samp no 10 processed...
# user num  2 samp no 1 processed...
# user num  2 samp no 2 processed...
# user num  2 samp no 3 processed...
# user num  2 samp no 4 processed...
# user num  2 samp no 5 processed...
# user num  2 samp no 6 processed...
# user num  2 samp no 7 processed...
# user num  2 samp no 8 processed...
# user num  2 samp no 9 processed...
# user num  2 samp no 10 processed...
# user num  3 samp no 1 processed...
# user num  3 samp no 2 processed...
# user num  3 samp no 3 processed...
# user num  3 samp no 4 processed...
# user num  3 samp no 5 processed...
# user num  3 samp no 6 processed...
# user num  3 samp no 7 processed...
# user num  3 samp no 8 processed...
# user num  3 samp no 9 processed...
# user num  3 samp no 10 processed...
# user num  4 samp no 1 processed...
# user num  4 samp no 2 processed...
# user num  4 samp no 3 processed...
# user num  4 samp no 4 processed...
# user num  4 samp no 5 processed...
# user num  4 samp no 6 processed...
# user num  4 samp no 7 processed...
# user num  4 samp no 8 processed...
# user num  4 samp no 9 processed...
# user num  4 samp no 10 processed...
# user num  5 samp no 1 processed...
# user num  5 samp no 2 processed...
# user num  5 samp no 3 processed...
# user num  5 samp no 4 processed...
# user num  5 samp no 5 processed...
# user num  5 samp no 6 processed...
# user num  5 samp no 7 processed...
# user num  5 samp no 8 processed...
# user num  5 samp no 9 processed...
# user num  5 samp no 10 processed...
# user num  6 samp no 1 processed...
# user num  6 samp no 2 processed...
# user num  6 samp no 3 processed...
# user num  6 samp no 4 processed...
# user num  6 samp no 5 processed...
# user num  6 samp no 6 processed...
# user num  6 samp no 7 processed...
# user num  6 samp no 8 processed...
# user num  6 samp no 9 processed...
# user num  6 samp no 10 processed...
# user num  7 samp no 1 processed...
# user num  7 samp no 2 processed...
# user num  7 samp no 3 processed...
# user num  7 samp no 4 processed...
# user num  7 samp no 5 processed...
# user num  7 samp no 6 processed...
# user num  7 samp no 7 processed...
# user num  7 samp no 8 processed...
# user num  7 samp no 9 processed...
# user num  7 samp no 10 processed...
# user num  8 samp no 1 processed...
# user num  8 samp no 2 processed...
# user num  8 samp no 3 processed...
# user num  8 samp no 4 processed...
# user num  8 samp no 5 processed...
# user num  8 samp no 6 processed...
# user num  8 samp no 7 processed...
# user num  8 samp no 8 processed...
# user num  8 samp no 9 processed...
# user num  8 samp no 10 processed...
# user num  9 samp no 1 processed...
# user num  9 samp no 2 processed...
# user num  9 samp no 3 processed...
# user num  9 samp no 4 processed...
# user num  9 samp no 5 processed...
# user num  9 samp no 6 processed...
# user num  9 samp no 7 processed...
# user num  9 samp no 8 processed...
# user num  9 samp no 9 processed...
# user num  9 samp no 10 processed...
# user num  10 samp no 1 processed...
# user num  10 samp no 2 processed...
# user num  10 samp no 3 processed...
# user num  10 samp no 4 processed...
# user num  10 samp no 5 processed...
# user num  10 samp no 6 processed...
# user num  10 samp no 7 processed...
# user num  10 samp no 8 processed...
# user num  10 samp no 9 processed...
# user num  10 samp no 10 processed...
# user num  11 samp no 1 processed...
# user num  11 samp no 2 processed...
# user num  11 samp no 3 processed...
# user num  11 samp no 4 processed...
# user num  11 samp no 5 processed...
# user num  11 samp no 6 processed...
# user num  11 samp no 7 processed...
# user num  11 samp no 8 processed...
# user num  11 samp no 9 processed...
# user num  11 samp no 10 processed...
# user num  12 samp no 1 processed...
# user num  12 samp no 2 processed...
# user num  12 samp no 3 processed...
# user num  12 samp no 4 processed...
# user num  12 samp no 5 processed...
# user num  12 samp no 6 processed...
# user num  12 samp no 7 processed...
# user num  12 samp no 8 processed...
# user num  12 samp no 9 processed...
# user num  12 samp no 10 processed...
# user num  13 samp no 1 processed...
# user num  13 samp no 2 processed...
# user num  13 samp no 3 processed...
# user num  13 samp no 4 processed...
# user num  13 samp no 5 processed...
# user num  13 samp no 6 processed...
# user num  13 samp no 7 processed...
# user num  13 samp no 8 processed...
# user num  13 samp no 9 processed...
# user num  13 samp no 10 processed...
# user num  14 samp no 1 processed...
# user num  14 samp no 2 processed...
# user num  14 samp no 3 processed...
# user num  14 samp no 4 processed...
# user num  14 samp no 5 processed...
# user num  14 samp no 6 processed...
# user num  14 samp no 7 processed...
# user num  14 samp no 8 processed...
# user num  14 samp no 9 processed...
# user num  14 samp no 10 processed...
# user num  15 samp no 1 processed...
# user num  15 samp no 2 processed...
# user num  15 samp no 3 processed...
# user num  15 samp no 4 processed...
# user num  15 samp no 5 processed...
# user num  15 samp no 6 processed...
# user num  15 samp no 7 processed...
# user num  15 samp no 8 processed...
# user num  15 samp no 9 processed...
# user num  15 samp no 10 processed...
# user num  16 samp no 1 processed...
# user num  16 samp no 2 processed...
# user num  16 samp no 3 processed...
# user num  16 samp no 4 processed...
# user num  16 samp no 5 processed...
# user num  16 samp no 6 processed...
# user num  16 samp no 7 processed...
# user num  16 samp no 8 processed...
# user num  16 samp no 9 processed...
# user num  16 samp no 10 processed...
# user num  17 samp no 1 processed...
# user num  17 samp no 2 processed...
# user num  17 samp no 3 processed...
# user num  17 samp no 4 processed...
# user num  17 samp no 5 processed...
# user num  17 samp no 6 processed...
# user num  17 samp no 7 processed...
# user num  17 samp no 8 processed...
# user num  17 samp no 9 processed...
# user num  17 samp no 10 processed...
# user num  18 samp no 1 processed...
# user num  18 samp no 2 processed...
# user num  18 samp no 3 processed...
# user num  18 samp no 4 processed...
# user num  18 samp no 5 processed...
# user num  18 samp no 6 processed...
# user num  18 samp no 7 processed...
# user num  18 samp no 8 processed...
# user num  18 samp no 9 processed...
# user num  18 samp no 10 processed...
# user num  19 samp no 1 processed...
# user num  19 samp no 2 processed...
# user num  19 samp no 3 processed...
# user num  19 samp no 4 processed...
# user num  19 samp no 5 processed...
# user num  19 samp no 6 processed...
# user num  19 samp no 7 processed...
# user num  19 samp no 8 processed...
# user num  19 samp no 9 processed...
# user num  19 samp no 10 processed...
# user num  20 samp no 1 processed...
# user num  20 samp no 2 processed...
# user num  20 samp no 3 processed...
# user num  20 samp no 4 processed...
# user num  20 samp no 5 processed...
# user num  20 samp no 6 processed...
# user num  20 samp no 7 processed...
# user num  20 samp no 8 processed...
# user num  20 samp no 9 processed...
# user num  20 samp no 10 processed...
# user num  21 samp no 1 processed...
# user num  21 samp no 2 processed...
# user num  21 samp no 3 processed...
# user num  21 samp no 4 processed...
# user num  21 samp no 5 processed...
# user num  21 samp no 6 processed...
# user num  21 samp no 7 processed...
# user num  21 samp no 8 processed...
# user num  21 samp no 9 processed...
# user num  21 samp no 10 processed...
# user num  22 samp no 1 processed...
# user num  22 samp no 2 processed...
# user num  22 samp no 3 processed...
# user num  22 samp no 4 processed...
# user num  22 samp no 5 processed...
# user num  22 samp no 6 processed...
# user num  22 samp no 7 processed...
# user num  22 samp no 8 processed...
# user num  22 samp no 9 processed...
# user num  22 samp no 10 processed...
# user num  23 samp no 1 processed...
# user num  23 samp no 2 processed...
# user num  23 samp no 3 processed...
# user num  23 samp no 4 processed...
# user num  23 samp no 5 processed...
# user num  23 samp no 6 processed...
# user num  23 samp no 7 processed...
# user num  23 samp no 8 processed...
# user num  23 samp no 9 processed...
# user num  23 samp no 10 processed...
# user num  24 samp no 1 processed...
# user num  24 samp no 2 processed...
# user num  24 samp no 3 processed...
# user num  24 samp no 4 processed...
# user num  24 samp no 5 processed...
# user num  24 samp no 6 processed...
# user num  24 samp no 7 processed...
# user num  24 samp no 8 processed...
# user num  24 samp no 9 processed...
# user num  24 samp no 10 processed...
# user num  25 samp no 1 processed...
# user num  25 samp no 2 processed...
# user num  25 samp no 3 processed...
# user num  25 samp no 4 processed...
# user num  25 samp no 5 processed...
# user num  25 samp no 6 processed...
# user num  25 samp no 7 processed...
# user num  25 samp no 8 processed...
# user num  25 samp no 9 processed...
# user num  25 samp no 10 processed...
# user num  26 samp no 1 processed...
# user num  26 samp no 2 processed...
# user num  26 samp no 3 processed...
# user num  26 samp no 4 processed...
# user num  26 samp no 5 processed...
# user num  26 samp no 6 processed...
# user num  26 samp no 7 processed...
# user num  26 samp no 8 processed...
# user num  26 samp no 9 processed...
# user num  26 samp no 10 processed...
# user num  27 samp no 1 processed...
# user num  27 samp no 2 processed...
# user num  27 samp no 3 processed...
# user num  27 samp no 4 processed...
# user num  27 samp no 5 processed...
# user num  27 samp no 6 processed...
# user num  27 samp no 7 processed...
# user num  27 samp no 8 processed...
# user num  27 samp no 9 processed...
# user num  27 samp no 10 processed...
# user num  28 samp no 1 processed...
# user num  28 samp no 2 processed...
# user num  28 samp no 3 processed...
# user num  28 samp no 4 processed...
# user num  28 samp no 5 processed...
# user num  28 samp no 6 processed...
# user num  28 samp no 7 processed...
# user num  28 samp no 8 processed...
# user num  28 samp no 9 processed...
# user num  28 samp no 10 processed...
# user num  29 samp no 1 processed...
# user num  29 samp no 2 processed...
# user num  29 samp no 3 processed...
# user num  29 samp no 4 processed...
# user num  29 samp no 5 processed...
# user num  29 samp no 6 processed...
# user num  29 samp no 7 processed...
# user num  29 samp no 8 processed...
# user num  29 samp no 9 processed...
# user num  29 samp no 10 processed...
# user num  30 samp no 1 processed...
# user num  30 samp no 2 processed...
# user num  30 samp no 3 processed...
# user num  30 samp no 4 processed...
# user num  30 samp no 5 processed...
# user num  30 samp no 6 processed...
# user num  30 samp no 7 processed...
# user num  30 samp no 8 processed...
# user num  30 samp no 9 processed...
# user num  30 samp no 10 processed...
# user num  31 samp no 1 processed...
# user num  31 samp no 2 processed...
# user num  31 samp no 3 processed...
# user num  31 samp no 4 processed...
# user num  31 samp no 5 processed...
# user num  31 samp no 6 processed...
# user num  31 samp no 7 processed...
# user num  31 samp no 8 processed...
# user num  31 samp no 9 processed...
# user num  31 samp no 10 processed...
# user num  32 samp no 1 processed...
# user num  32 samp no 2 processed...
# user num  32 samp no 3 processed...
# user num  32 samp no 4 processed...
# user num  32 samp no 5 processed...
# user num  32 samp no 6 processed...
# user num  32 samp no 7 processed...
# user num  32 samp no 8 processed...
# user num  32 samp no 9 processed...
# user num  32 samp no 10 processed...
# user num  33 samp no 1 processed...
# user num  33 samp no 2 processed...
# user num  33 samp no 3 processed...
# user num  33 samp no 4 processed...
# user num  33 samp no 5 processed...
# user num  33 samp no 6 processed...
# user num  33 samp no 7 processed...
# user num  33 samp no 8 processed...
# user num  33 samp no 9 processed...
# user num  33 samp no 10 processed...
# user num  34 samp no 1 processed...
# user num  34 samp no 2 processed...
# user num  34 samp no 3 processed...
# user num  34 samp no 4 processed...
# user num  34 samp no 5 processed...
# user num  34 samp no 6 processed...
# user num  34 samp no 7 processed...
# user num  34 samp no 8 processed...
# user num  34 samp no 9 processed...
# user num  34 samp no 10 processed...
# user num  35 samp no 1 processed...
# user num  35 samp no 2 processed...
# user num  35 samp no 3 processed...
# user num  35 samp no 4 processed...
# user num  35 samp no 5 processed...
# user num  35 samp no 6 processed...
# user num  35 samp no 7 processed...
# user num  35 samp no 8 processed...
# user num  35 samp no 9 processed...
# user num  35 samp no 10 processed...
# user num  36 samp no 1 processed...
# user num  36 samp no 2 processed...
# user num  36 samp no 3 processed...
# user num  36 samp no 4 processed...
# user num  36 samp no 5 processed...
# user num  36 samp no 6 processed...
# user num  36 samp no 7 processed...
# user num  36 samp no 8 processed...
# user num  36 samp no 9 processed...
# user num  36 samp no 10 processed...
# user num  37 samp no 1 processed...
# user num  37 samp no 2 processed...
# user num  37 samp no 3 processed...
# user num  37 samp no 4 processed...
# user num  37 samp no 5 processed...
# user num  37 samp no 6 processed...
# user num  37 samp no 7 processed...
# user num  37 samp no 8 processed...
# user num  37 samp no 9 processed...
# user num  37 samp no 10 processed...
# user num  38 samp no 1 processed...
# user num  38 samp no 2 processed...
# user num  38 samp no 3 processed...
# user num  38 samp no 4 processed...
# user num  38 samp no 5 processed...
# user num  38 samp no 6 processed...
# user num  38 samp no 7 processed...
# user num  38 samp no 8 processed...
# user num  38 samp no 9 processed...
# user num  38 samp no 10 processed...
# user num  39 samp no 1 processed...
# user num  39 samp no 2 processed...
# user num  39 samp no 3 processed...
# user num  39 samp no 4 processed...
# user num  39 samp no 5 processed...
# user num  39 samp no 6 processed...
# user num  39 samp no 7 processed...
# user num  39 samp no 8 processed...
# user num  39 samp no 9 processed...
# user num  39 samp no 10 processed...
# user num  40 samp no 1 processed...
# user num  40 samp no 2 processed...
# user num  40 samp no 3 processed...
# user num  40 samp no 4 processed...
# user num  40 samp no 5 processed...
# user num  40 samp no 6 processed...
# user num  40 samp no 7 processed...
# user num  40 samp no 8 processed...
# user num  40 samp no 9 processed...
# user num  40 samp no 10 processed...

# %%
# display the image
plt.imshow(images[389,:,:],cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 91.5, 111.5, -0.5)

# %%
ind=0
for i in range(5):
  for j in range(5):
    ind = ind+1
    s = np.random.randint(0,400)
    currIm = images[s,:,:]
    currId = label[s]
    plt.figure(1,(10,10))
    plt.subplot(5,5,ind)
    plt.imshow(currIm,cmap='gray')
    plt.title(str(int(currId)))
    plt.axis('off')

# %%
from sklearn import svm,model_selection,metrics
import pandas as pd
X = data.copy()
y = label.copy()


# split the data into 70:30 ratio
Xtrain,Xtest,ytrain,ytest = model_selection.train_test_split(X,y,test_size=0.3,random_state=5)
print(Xtrain.shape,ytrain.shape)
print(Xtest.shape,ytest.shape)

ker = ['poly','linear','rbf']
c_value = [1,2,3]

# pre allocation of the result variable
result = np.zeros((len(ker),len(c_value)))
for i in range(len(ker)):
  for j in range(len(c_value)):
    # create the svm classifier
    orl_svm_model = svm.SVC(kernel=ker[i],gamma='scale',C=c_value[j])

    # train the model
    orl_svm_model = orl_svm_model.fit(Xtrain,ytrain)

    # predict the labels
    ypred = orl_svm_model.predict(Xtest)

    # accuracy
    acc = metrics.accuracy_score(ypred,ytest)
    #print("accuracy:", acc)
    result[i,j]=acc
print(result)

ResultDF = pd.DataFrame(result,index=ker,columns=["C=1","C=2","C=3"])
ResultDF
# Out:
# (280, 10304) (280,)
# (120, 10304) (120,)
# [[0.94166667 0.94166667 0.94166667]
#  [0.95       0.95       0.95      ]
#  [0.88333333 0.95       0.95      ]]
#              C=1       C=2       C=3
# poly    0.941667  0.941667  0.941667
# linear  0.950000  0.950000  0.950000
# rbf     0.883333  0.950000  0.950000

# %%
# !unzip '/content/drive/MyDrive/orl_face.zip' -d '/content/drive/MyDrive'
# Out:
# Archive:  /content/drive/MyDrive/orl_face.zip
#    creating: /content/drive/MyDrive/orl_face/
#   inflating: /content/drive/MyDrive/orl_face/.DS_Store
#    creating: /content/drive/MyDrive/__MACOSX/
#    creating: /content/drive/MyDrive/__MACOSX/orl_face/
#   inflating: /content/drive/MyDrive/__MACOSX/orl_face/._.DS_Store
#    creating: /content/drive/MyDrive/orl_face/u1/
#   inflating: /content/drive/MyDrive/orl_face/u1/1.png
#    creating: /content/drive/MyDrive/__MACOSX/orl_face/u1/
#   inflating: /content/drive/MyDrive/__MACOSX/orl_face/u1/._1.png
#   inflating: /content/drive/MyDrive/orl_face/u1/10.png
#   inflating: /content/drive/MyDrive/orl_face/u1/2.png
#   inflating: /content/drive/MyDrive/orl_face/u1/3.png
#   inflating: /content/drive/MyDrive/orl_face/u1/4.png
#   inflating: /content/drive/MyDrive/orl_face/u1/5.png
#   inflating: /content/drive/MyDrive/orl_face/u1/6.png
#   inflating: /content/drive/MyDrive/orl_face/u1/7.png
#   inflating: /content/drive/MyDrive/orl_face/u1/8.png
#   inflating: /content/drive/MyDrive/orl_face/u1/9.png
#    creating: /content/drive/MyDrive/orl_face/u10/
#   inflating: /content/drive/MyDrive/orl_face/u10/1.png
#   inflating: /content/drive/MyDrive/orl_face/u10/10.png
#   inflating: /content/drive/MyDrive/orl_face/u10/2.png
#   inflating: /content/drive/MyDrive/orl_face/u10/3.png
#   inflating: /content/drive/MyDrive/orl_face/u10/4.png
#   inflating: /content/drive/MyDrive/orl_face/u10/5.png
#   inflating: /content/drive/MyDrive/orl_face/u10/6.png
#   inflating: /content/drive/MyDrive/orl_face/u10/7.png
#   inflating: /content/drive/MyDrive/orl_face/u10/8.png
#   inflating: /content/drive/MyDrive/orl_face/u10/9.png
#    creating: /content/drive/MyDrive/orl_face/u11/
#   inflating: /content/drive/MyDrive/orl_face/u11/1.png
#   inflating: /content/drive/MyDrive/orl_face/u11/10.png
#   inflating: /content/drive/MyDrive/orl_face/u11/2.png
#   inflating: /content/drive/MyDrive/orl_face/u11/3.png
#   inflating: /content/drive/MyDrive/orl_face/u11/4.png
#   inflating: /content/drive/MyDrive/orl_face/u11/5.png
#   inflating: /content/drive/MyDrive/orl_face/u11/6.png
#   inflating: /content/drive/MyDrive/orl_face/u11/7.png
#   inflating: /content/drive/MyDrive/orl_face/u11/8.png
#   inflating: /content/drive/MyDrive/orl_face/u11/9.png
#    creating: /content/drive/MyDrive/orl_face/u12/
#   inflating: /content/drive/MyDrive/orl_face/u12/1.png
#   inflating: /content/drive/MyDrive/orl_face/u12/10.png
#   inflating: /content/drive/MyDrive/orl_face/u12/2.png
#   inflating: /content/drive/MyDrive/orl_face/u12/3.png
#   inflating: /content/drive/MyDrive/orl_face/u12/4.png
#   inflating: /content/drive/MyDrive/orl_face/u12/5.png
#   inflating: /content/drive/MyDrive/orl_face/u12/6.png
#   inflating: /content/drive/MyDrive/orl_face/u12/7.png
#   inflating: /content/drive/MyDrive/orl_face/u12/8.png
#   inflating: /content/drive/MyDrive/orl_face/u12/9.png
#    creating: /content/drive/MyDrive/orl_face/u13/
#   inflating: /content/drive/MyDrive/orl_face/u13/1.png
#   inflating: /content/drive/MyDrive/orl_face/u13/10.png
#   inflating: /content/drive/MyDrive/orl_face/u13/2.png
#   inflating: /content/drive/MyDrive/orl_face/u13/3.png
#   inflating: /content/drive/MyDrive/orl_face/u13/4.png
#   inflating: /content/drive/MyDrive/orl_face/u13/5.png
#   inflating: /content/drive/MyDrive/orl_face/u13/6.png
#   inflating: /content/drive/MyDrive/orl_face/u13/7.png
#   inflating: /content/drive/MyDrive/orl_face/u13/8.png
#   inflating: /content/drive/MyDrive/orl_face/u13/9.png
#    creating: /content/drive/MyDrive/orl_face/u14/
#   inflating: /content/drive/MyDrive/orl_face/u14/1.png
#   inflating: /content/drive/MyDrive/orl_face/u14/10.png
#   inflating: /content/drive/MyDrive/orl_face/u14/2.png
#   inflating: /content/drive/MyDrive/orl_face/u14/3.png
#   inflating: /content/drive/MyDrive/orl_face/u14/4.png
#   inflating: /content/drive/MyDrive/orl_face/u14/5.png
#   inflating: /content/drive/MyDrive/orl_face/u14/6.png
#   inflating: /content/drive/MyDrive/orl_face/u14/7.png
#   inflating: /content/drive/MyDrive/orl_face/u14/8.png
#   inflating: /content/drive/MyDrive/orl_face/u14/9.png
#    creating: /content/drive/MyDrive/orl_face/u15/
#   inflating: /content/drive/MyDrive/orl_face/u15/1.png
#   inflating: /content/drive/MyDrive/orl_face/u15/10.png
#   inflating: /content/drive/MyDrive/orl_face/u15/2.png
#   inflating: /content/drive/MyDrive/orl_face/u15/3.png
#   inflating: /content/drive/MyDrive/orl_face/u15/4.png
#   inflating: /content/drive/MyDrive/orl_face/u15/5.png
#   inflating: /content/drive/MyDrive/orl_face/u15/6.png
#   inflating: /content/drive/MyDrive/orl_face/u15/7.png
#   inflating: /content/drive/MyDrive/orl_face/u15/8.png
#   inflating: /content/drive/MyDrive/orl_face/u15/9.png
#    creating: /content/drive/MyDrive/orl_face/u16/
#   inflating: /content/drive/MyDrive/orl_face/u16/1.png
#   inflating: /content/drive/MyDrive/orl_face/u16/10.png
#   inflating: /content/drive/MyDrive/orl_face/u16/2.png
#   inflating: /content/drive/MyDrive/orl_face/u16/3.png
#   inflating: /content/drive/MyDrive/orl_face/u16/4.png
#   inflating: /content/drive/MyDrive/orl_face/u16/5.png
#   inflating: /content/drive/MyDrive/orl_face/u16/6.png
#   inflating: /content/drive/MyDrive/orl_face/u16/7.png
#   inflating: /content/drive/MyDrive/orl_face/u16/8.png
#   inflating: /content/drive/MyDrive/orl_face/u16/9.png
#    creating: /content/drive/MyDrive/orl_face/u17/
#   inflating: /content/drive/MyDrive/orl_face/u17/1.png
#   inflating: /content/drive/MyDrive/orl_face/u17/10.png
#   inflating: /content/drive/MyDrive/orl_face/u17/2.png
#   inflating: /content/drive/MyDrive/orl_face/u17/3.png
#   inflating: /content/drive/MyDrive/orl_face/u17/4.png
#   inflating: /content/drive/MyDrive/orl_face/u17/5.png
#   inflating: /content/drive/MyDrive/orl_face/u17/6.png
#   inflating: /content/drive/MyDrive/orl_face/u17/7.png
#   inflating: /content/drive/MyDrive/orl_face/u17/8.png
#   inflating: /content/drive/MyDrive/orl_face/u17/9.png
#    creating: /content/drive/MyDrive/orl_face/u18/
#   inflating: /content/drive/MyDrive/orl_face/u18/1.png
#   inflating: /content/drive/MyDrive/orl_face/u18/10.png
#   inflating: /content/drive/MyDrive/orl_face/u18/2.png
#   inflating: /content/drive/MyDrive/orl_face/u18/3.png
#   inflating: /content/drive/MyDrive/orl_face/u18/4.png
#   inflating: /content/drive/MyDrive/orl_face/u18/5.png
#   inflating: /content/drive/MyDrive/orl_face/u18/6.png
#   inflating: /content/drive/MyDrive/orl_face/u18/7.png
#   inflating: /content/drive/MyDrive/orl_face/u18/8.png
#   inflating: /content/drive/MyDrive/orl_face/u18/9.png
#    creating: /content/drive/MyDrive/orl_face/u19/
#   inflating: /content/drive/MyDrive/orl_face/u19/1.png
#   inflating: /content/drive/MyDrive/orl_face/u19/10.png
#   inflating: /content/drive/MyDrive/orl_face/u19/2.png
#   inflating: /content/drive/MyDrive/orl_face/u19/3.png
#   inflating: /content/drive/MyDrive/orl_face/u19/4.png
#   inflating: /content/drive/MyDrive/orl_face/u19/5.png
#   inflating: /content/drive/MyDrive/orl_face/u19/6.png
#   inflating: /content/drive/MyDrive/orl_face/u19/7.png
#   inflating: /content/drive/MyDrive/orl_face/u19/8.png
#   inflating: /content/drive/MyDrive/orl_face/u19/9.png
#    creating: /content/drive/MyDrive/orl_face/u2/
#   inflating: /content/drive/MyDrive/orl_face/u2/1.png
#   inflating: /content/drive/MyDrive/orl_face/u2/10.png
#   inflating: /content/drive/MyDrive/orl_face/u2/2.png
#   inflating: /content/drive/MyDrive/orl_face/u2/3.png
#   inflating: /content/drive/MyDrive/orl_face/u2/4.png
#   inflating: /content/drive/MyDrive/orl_face/u2/5.png
#   inflating: /content/drive/MyDrive/orl_face/u2/6.png
#   inflating: /content/drive/MyDrive/orl_face/u2/7.png
#   inflating: /content/drive/MyDrive/orl_face/u2/8.png
#   inflating: /content/drive/MyDrive/orl_face/u2/9.png
#    creating: /content/drive/MyDrive/orl_face/u20/
#   inflating: /content/drive/MyDrive/orl_face/u20/1.png
#   inflating: /content/drive/MyDrive/orl_face/u20/10.png
#   inflating: /content/drive/MyDrive/orl_face/u20/2.png
#   inflating: /content/drive/MyDrive/orl_face/u20/3.png
#   inflating: /content/drive/MyDrive/orl_face/u20/4.png
#   inflating: /content/drive/MyDrive/orl_face/u20/5.png
#   inflating: /content/drive/MyDrive/orl_face/u20/6.png
#   inflating: /content/drive/MyDrive/orl_face/u20/7.png
#   inflating: /content/drive/MyDrive/orl_face/u20/8.png
#   inflating: /content/drive/MyDrive/orl_face/u20/9.png
#    creating: /content/drive/MyDrive/orl_face/u21/
#   inflating: /content/drive/MyDrive/orl_face/u21/1.png
#   inflating: /content/drive/MyDrive/orl_face/u21/10.png
#   inflating: /content/drive/MyDrive/orl_face/u21/2.png
#   inflating: /content/drive/MyDrive/orl_face/u21/3.png
#   inflating: /content/drive/MyDrive/orl_face/u21/4.png
#   inflating: /content/drive/MyDrive/orl_face/u21/5.png
#   inflating: /content/drive/MyDrive/orl_face/u21/6.png
#   inflating: /content/drive/MyDrive/orl_face/u21/7.png
#   inflating: /content/drive/MyDrive/orl_face/u21/8.png
#   inflating: /content/drive/MyDrive/orl_face/u21/9.png
#    creating: /content/drive/MyDrive/orl_face/u22/
#   inflating: /content/drive/MyDrive/orl_face/u22/1.png
#   inflating: /content/drive/MyDrive/orl_face/u22/10.png
#   inflating: /content/drive/MyDrive/orl_face/u22/2.png
#   inflating: /content/drive/MyDrive/orl_face/u22/3.png
#   inflating: /content/drive/MyDrive/orl_face/u22/4.png
#   inflating: /content/drive/MyDrive/orl_face/u22/5.png
#   inflating: /content/drive/MyDrive/orl_face/u22/6.png
#   inflating: /content/drive/MyDrive/orl_face/u22/7.png
#   inflating: /content/drive/MyDrive/orl_face/u22/8.png
#   inflating: /content/drive/MyDrive/orl_face/u22/9.png
#    creating: /content/drive/MyDrive/orl_face/u23/
#   inflating: /content/drive/MyDrive/orl_face/u23/1.png
#   inflating: /content/drive/MyDrive/orl_face/u23/10.png
#   inflating: /content/drive/MyDrive/orl_face/u23/2.png
#   inflating: /content/drive/MyDrive/orl_face/u23/3.png
#   inflating: /content/drive/MyDrive/orl_face/u23/4.png
#   inflating: /content/drive/MyDrive/orl_face/u23/5.png
#   inflating: /content/drive/MyDrive/orl_face/u23/6.png
#   inflating: /content/drive/MyDrive/orl_face/u23/7.png
#   inflating: /content/drive/MyDrive/orl_face/u23/8.png
#   inflating: /content/drive/MyDrive/orl_face/u23/9.png
#    creating: /content/drive/MyDrive/orl_face/u24/
#   inflating: /content/drive/MyDrive/orl_face/u24/1.png
#   inflating: /content/drive/MyDrive/orl_face/u24/10.png
#   inflating: /content/drive/MyDrive/orl_face/u24/2.png
#   inflating: /content/drive/MyDrive/orl_face/u24/3.png
#   inflating: /content/drive/MyDrive/orl_face/u24/4.png
#   inflating: /content/drive/MyDrive/orl_face/u24/5.png
#   inflating: /content/drive/MyDrive/orl_face/u24/6.png
#   inflating: /content/drive/MyDrive/orl_face/u24/7.png
#   inflating: /content/drive/MyDrive/orl_face/u24/8.png
#   inflating: /content/drive/MyDrive/orl_face/u24/9.png
#    creating: /content/drive/MyDrive/orl_face/u25/
#   inflating: /content/drive/MyDrive/orl_face/u25/1.png
#   inflating: /content/drive/MyDrive/orl_face/u25/10.png
#   inflating: /content/drive/MyDrive/orl_face/u25/2.png
#   inflating: /content/drive/MyDrive/orl_face/u25/3.png
#   inflating: /content/drive/MyDrive/orl_face/u25/4.png
#   inflating: /content/drive/MyDrive/orl_face/u25/5.png
#   inflating: /content/drive/MyDrive/orl_face/u25/6.png
#   inflating: /content/drive/MyDrive/orl_face/u25/7.png
#   inflating: /content/drive/MyDrive/orl_face/u25/8.png
#   inflating: /content/drive/MyDrive/orl_face/u25/9.png
#    creating: /content/drive/MyDrive/orl_face/u26/
#   inflating: /content/drive/MyDrive/orl_face/u26/1.png
#   inflating: /content/drive/MyDrive/orl_face/u26/10.png
#   inflating: /content/drive/MyDrive/orl_face/u26/2.png
#   inflating: /content/drive/MyDrive/orl_face/u26/3.png
#   inflating: /content/drive/MyDrive/orl_face/u26/4.png
#   inflating: /content/drive/MyDrive/orl_face/u26/5.png
#   inflating: /content/drive/MyDrive/orl_face/u26/6.png
#   inflating: /content/drive/MyDrive/orl_face/u26/7.png
#   inflating: /content/drive/MyDrive/orl_face/u26/8.png
#   inflating: /content/drive/MyDrive/orl_face/u26/9.png
#    creating: /content/drive/MyDrive/orl_face/u27/
#   inflating: /content/drive/MyDrive/orl_face/u27/1.png
#   inflating: /content/drive/MyDrive/orl_face/u27/10.png
#   inflating: /content/drive/MyDrive/orl_face/u27/2.png
#   inflating: /content/drive/MyDrive/orl_face/u27/3.png
#   inflating: /content/drive/MyDrive/orl_face/u27/4.png
#   inflating: /content/drive/MyDrive/orl_face/u27/5.png
#   inflating: /content/drive/MyDrive/orl_face/u27/6.png
#   inflating: /content/drive/MyDrive/orl_face/u27/7.png
#   inflating: /content/drive/MyDrive/orl_face/u27/8.png
#   inflating: /content/drive/MyDrive/orl_face/u27/9.png
#    creating: /content/drive/MyDrive/orl_face/u28/
#   inflating: /content/drive/MyDrive/orl_face/u28/1.png
#   inflating: /content/drive/MyDrive/orl_face/u28/10.png
#   inflating: /content/drive/MyDrive/orl_face/u28/2.png
#   inflating: /content/drive/MyDrive/orl_face/u28/3.png
#   inflating: /content/drive/MyDrive/orl_face/u28/4.png
#   inflating: /content/drive/MyDrive/orl_face/u28/5.png
#   inflating: /content/drive/MyDrive/orl_face/u28/6.png
#   inflating: /content/drive/MyDrive/orl_face/u28/7.png
#   inflating: /content/drive/MyDrive/orl_face/u28/8.png
#   inflating: /content/drive/MyDrive/orl_face/u28/9.png
#    creating: /content/drive/MyDrive/orl_face/u29/
#   inflating: /content/drive/MyDrive/orl_face/u29/1.png
#   inflating: /content/drive/MyDrive/orl_face/u29/10.png
#   inflating: /content/drive/MyDrive/orl_face/u29/2.png
#   inflating: /content/drive/MyDrive/orl_face/u29/3.png
#   inflating: /content/drive/MyDrive/orl_face/u29/4.png
#   inflating: /content/drive/MyDrive/orl_face/u29/5.png
#   inflating: /content/drive/MyDrive/orl_face/u29/6.png
#   inflating: /content/drive/MyDrive/orl_face/u29/7.png
#   inflating: /content/drive/MyDrive/orl_face/u29/8.png
#   inflating: /content/drive/MyDrive/orl_face/u29/9.png
#    creating: /content/drive/MyDrive/orl_face/u3/
#   inflating: /content/drive/MyDrive/orl_face/u3/1.png
#   inflating: /content/drive/MyDrive/orl_face/u3/10.png
#   inflating: /content/drive/MyDrive/orl_face/u3/2.png
#   inflating: /content/drive/MyDrive/orl_face/u3/3.png
#   inflating: /content/drive/MyDrive/orl_face/u3/4.png
#   inflating: /content/drive/MyDrive/orl_face/u3/5.png
#   inflating: /content/drive/MyDrive/orl_face/u3/6.png
#   inflating: /content/drive/MyDrive/orl_face/u3/7.png
#   inflating: /content/drive/MyDrive/orl_face/u3/8.png
#   inflating: /content/drive/MyDrive/orl_face/u3/9.png
#    creating: /content/drive/MyDrive/orl_face/u30/
#   inflating: /content/drive/MyDrive/orl_face/u30/1.png
#   inflating: /content/drive/MyDrive/orl_face/u30/10.png
#   inflating: /content/drive/MyDrive/orl_face/u30/2.png
#   inflating: /content/drive/MyDrive/orl_face/u30/3.png
#   inflating: /content/drive/MyDrive/orl_face/u30/4.png
#   inflating: /content/drive/MyDrive/orl_face/u30/5.png
#   inflating: /content/drive/MyDrive/orl_face/u30/6.png
#   inflating: /content/drive/MyDrive/orl_face/u30/7.png
#   inflating: /content/drive/MyDrive/orl_face/u30/8.png
#   inflating: /content/drive/MyDrive/orl_face/u30/9.png
#    creating: /content/drive/MyDrive/orl_face/u31/
#   inflating: /content/drive/MyDrive/orl_face/u31/1.png
#   inflating: /content/drive/MyDrive/orl_face/u31/10.png
#   inflating: /content/drive/MyDrive/orl_face/u31/2.png
#   inflating: /content/drive/MyDrive/orl_face/u31/3.png
#   inflating: /content/drive/MyDrive/orl_face/u31/4.png
#   inflating: /content/drive/MyDrive/orl_face/u31/5.png
#   inflating: /content/drive/MyDrive/orl_face/u31/6.png
#   inflating: /content/drive/MyDrive/orl_face/u31/7.png
#   inflating: /content/drive/MyDrive/orl_face/u31/8.png
#   inflating: /content/drive/MyDrive/orl_face/u31/9.png
#    creating: /content/drive/MyDrive/orl_face/u32/
#   inflating: /content/drive/MyDrive/orl_face/u32/1.png
#   inflating: /content/drive/MyDrive/orl_face/u32/10.png
#   inflating: /content/drive/MyDrive/orl_face/u32/2.png
#   inflating: /content/drive/MyDrive/orl_face/u32/3.png
#   inflating: /content/drive/MyDrive/orl_face/u32/4.png
#   inflating: /content/drive/MyDrive/orl_face/u32/5.png
#   inflating: /content/drive/MyDrive/orl_face/u32/6.png
#   inflating: /content/drive/MyDrive/orl_face/u32/7.png
#   inflating: /content/drive/MyDrive/orl_face/u32/8.png
#   inflating: /content/drive/MyDrive/orl_face/u32/9.png
#    creating: /content/drive/MyDrive/orl_face/u33/
#   inflating: /content/drive/MyDrive/orl_face/u33/1.png
#   inflating: /content/drive/MyDrive/orl_face/u33/10.png
#   inflating: /content/drive/MyDrive/orl_face/u33/2.png
#   inflating: /content/drive/MyDrive/orl_face/u33/3.png
#   inflating: /content/drive/MyDrive/orl_face/u33/4.png
#   inflating: /content/drive/MyDrive/orl_face/u33/5.png
#   inflating: /content/drive/MyDrive/orl_face/u33/6.png
#   inflating: /content/drive/MyDrive/orl_face/u33/7.png
#   inflating: /content/drive/MyDrive/orl_face/u33/8.png
#   inflating: /content/drive/MyDrive/orl_face/u33/9.png
#    creating: /content/drive/MyDrive/orl_face/u34/
#   inflating: /content/drive/MyDrive/orl_face/u34/1.png
#   inflating: /content/drive/MyDrive/orl_face/u34/10.png
#   inflating: /content/drive/MyDrive/orl_face/u34/2.png
#   inflating: /content/drive/MyDrive/orl_face/u34/3.png
#   inflating: /content/drive/MyDrive/orl_face/u34/4.png
#   inflating: /content/drive/MyDrive/orl_face/u34/5.png
#   inflating: /content/drive/MyDrive/orl_face/u34/6.png
#   inflating: /content/drive/MyDrive/orl_face/u34/7.png
#   inflating: /content/drive/MyDrive/orl_face/u34/8.png
#   inflating: /content/drive/MyDrive/orl_face/u34/9.png
#    creating: /content/drive/MyDrive/orl_face/u35/
#   inflating: /content/drive/MyDrive/orl_face/u35/1.png
#   inflating: /content/drive/MyDrive/orl_face/u35/10.png
#   inflating: /content/drive/MyDrive/orl_face/u35/2.png
#   inflating: /content/drive/MyDrive/orl_face/u35/3.png
#   inflating: /content/drive/MyDrive/orl_face/u35/4.png
#   inflating: /content/drive/MyDrive/orl_face/u35/5.png
#   inflating: /content/drive/MyDrive/orl_face/u35/6.png
#   inflating: /content/drive/MyDrive/orl_face/u35/7.png
#   inflating: /content/drive/MyDrive/orl_face/u35/8.png
#   inflating: /content/drive/MyDrive/orl_face/u35/9.png
#    creating: /content/drive/MyDrive/orl_face/u36/
#   inflating: /content/drive/MyDrive/orl_face/u36/1.png
#   inflating: /content/drive/MyDrive/orl_face/u36/10.png
#   inflating: /content/drive/MyDrive/orl_face/u36/2.png
#   inflating: /content/drive/MyDrive/orl_face/u36/3.png
#   inflating: /content/drive/MyDrive/orl_face/u36/4.png
#   inflating: /content/drive/MyDrive/orl_face/u36/5.png
#   inflating: /content/drive/MyDrive/orl_face/u36/6.png
#   inflating: /content/drive/MyDrive/orl_face/u36/7.png
#   inflating: /content/drive/MyDrive/orl_face/u36/8.png
#   inflating: /content/drive/MyDrive/orl_face/u36/9.png
#    creating: /content/drive/MyDrive/orl_face/u37/
#   inflating: /content/drive/MyDrive/orl_face/u37/1.png
#   inflating: /content/drive/MyDrive/orl_face/u37/10.png
#   inflating: /content/drive/MyDrive/orl_face/u37/2.png
#   inflating: /content/drive/MyDrive/orl_face/u37/3.png
#   inflating: /content/drive/MyDrive/orl_face/u37/4.png
#   inflating: /content/drive/MyDrive/orl_face/u37/5.png
#   inflating: /content/drive/MyDrive/orl_face/u37/6.png
#   inflating: /content/drive/MyDrive/orl_face/u37/7.png
#   inflating: /content/drive/MyDrive/orl_face/u37/8.png
#   inflating: /content/drive/MyDrive/orl_face/u37/9.png
#    creating: /content/drive/MyDrive/orl_face/u38/
#   inflating: /content/drive/MyDrive/orl_face/u38/1.png
#   inflating: /content/drive/MyDrive/orl_face/u38/10.png
#   inflating: /content/drive/MyDrive/orl_face/u38/2.png
#   inflating: /content/drive/MyDrive/orl_face/u38/3.png
#   inflating: /content/drive/MyDrive/orl_face/u38/4.png
#   inflating: /content/drive/MyDrive/orl_face/u38/5.png
#   inflating: /content/drive/MyDrive/orl_face/u38/6.png
#   inflating: /content/drive/MyDrive/orl_face/u38/7.png
#   inflating: /content/drive/MyDrive/orl_face/u38/8.png
#   inflating: /content/drive/MyDrive/orl_face/u38/9.png
#    creating: /content/drive/MyDrive/orl_face/u39/
#   inflating: /content/drive/MyDrive/orl_face/u39/1.png
#   inflating: /content/drive/MyDrive/orl_face/u39/10.png
#   inflating: /content/drive/MyDrive/orl_face/u39/2.png
#   inflating: /content/drive/MyDrive/orl_face/u39/3.png
#   inflating: /content/drive/MyDrive/orl_face/u39/4.png
#   inflating: /content/drive/MyDrive/orl_face/u39/5.png
#   inflating: /content/drive/MyDrive/orl_face/u39/6.png
#   inflating: /content/drive/MyDrive/orl_face/u39/7.png
#   inflating: /content/drive/MyDrive/orl_face/u39/8.png
#   inflating: /content/drive/MyDrive/orl_face/u39/9.png
#    creating: /content/drive/MyDrive/orl_face/u4/
#   inflating: /content/drive/MyDrive/orl_face/u4/1.png
#   inflating: /content/drive/MyDrive/orl_face/u4/10.png
#   inflating: /content/drive/MyDrive/orl_face/u4/2.png
#   inflating: /content/drive/MyDrive/orl_face/u4/3.png
#   inflating: /content/drive/MyDrive/orl_face/u4/4.png
#   inflating: /content/drive/MyDrive/orl_face/u4/5.png
#   inflating: /content/drive/MyDrive/orl_face/u4/6.png
#   inflating: /content/drive/MyDrive/orl_face/u4/7.png
#   inflating: /content/drive/MyDrive/orl_face/u4/8.png
#   inflating: /content/drive/MyDrive/orl_face/u4/9.png
#    creating: /content/drive/MyDrive/orl_face/u40/
#   inflating: /content/drive/MyDrive/orl_face/u40/1.png
#   inflating: /content/drive/MyDrive/orl_face/u40/10.png
#   inflating: /content/drive/MyDrive/orl_face/u40/2.png
#   inflating: /content/drive/MyDrive/orl_face/u40/3.png
#   inflating: /content/drive/MyDrive/orl_face/u40/4.png
#   inflating: /content/drive/MyDrive/orl_face/u40/5.png
#   inflating: /content/drive/MyDrive/orl_face/u40/6.png
#   inflating: /content/drive/MyDrive/orl_face/u40/7.png
#   inflating: /content/drive/MyDrive/orl_face/u40/8.png
#   inflating: /content/drive/MyDrive/orl_face/u40/9.png
#    creating: /content/drive/MyDrive/orl_face/u5/
#   inflating: /content/drive/MyDrive/orl_face/u5/1.png
#   inflating: /content/drive/MyDrive/orl_face/u5/10.png
#   inflating: /content/drive/MyDrive/orl_face/u5/2.png
#   inflating: /content/drive/MyDrive/orl_face/u5/3.png
#   inflating: /content/drive/MyDrive/orl_face/u5/4.png
#   inflating: /content/drive/MyDrive/orl_face/u5/5.png
#   inflating: /content/drive/MyDrive/orl_face/u5/6.png
#   inflating: /content/drive/MyDrive/orl_face/u5/7.png
#   inflating: /content/drive/MyDrive/orl_face/u5/8.png
#   inflating: /content/drive/MyDrive/orl_face/u5/9.png
#    creating: /content/drive/MyDrive/orl_face/u6/
#   inflating: /content/drive/MyDrive/orl_face/u6/1.png
#   inflating: /content/drive/MyDrive/orl_face/u6/10.png
#   inflating: /content/drive/MyDrive/orl_face/u6/2.png
#   inflating: /content/drive/MyDrive/orl_face/u6/3.png
#   inflating: /content/drive/MyDrive/orl_face/u6/4.png
#   inflating: /content/drive/MyDrive/orl_face/u6/5.png
#   inflating: /content/drive/MyDrive/orl_face/u6/6.png
#   inflating: /content/drive/MyDrive/orl_face/u6/7.png
#   inflating: /content/drive/MyDrive/orl_face/u6/8.png
#   inflating: /content/drive/MyDrive/orl_face/u6/9.png
#    creating: /content/drive/MyDrive/orl_face/u7/
#   inflating: /content/drive/MyDrive/orl_face/u7/1.png
#   inflating: /content/drive/MyDrive/orl_face/u7/10.png
#   inflating: /content/drive/MyDrive/orl_face/u7/2.png
#   inflating: /content/drive/MyDrive/orl_face/u7/3.png
#   inflating: /content/drive/MyDrive/orl_face/u7/4.png
#   inflating: /content/drive/MyDrive/orl_face/u7/5.png
#   inflating: /content/drive/MyDrive/orl_face/u7/6.png
#   inflating: /content/drive/MyDrive/orl_face/u7/7.png
#   inflating: /content/drive/MyDrive/orl_face/u7/8.png
#   inflating: /content/drive/MyDrive/orl_face/u7/9.png
#    creating: /content/drive/MyDrive/orl_face/u8/
#   inflating: /content/drive/MyDrive/orl_face/u8/1.png
#   inflating: /content/drive/MyDrive/orl_face/u8/10.png
#   inflating: /content/drive/MyDrive/orl_face/u8/2.png
#   inflating: /content/drive/MyDrive/orl_face/u8/3.png
#   inflating: /content/drive/MyDrive/orl_face/u8/4.png
#   inflating: /content/drive/MyDrive/orl_face/u8/5.png
#   inflating: /content/drive/MyDrive/orl_face/u8/6.png
#   inflating: /content/drive/MyDrive/orl_face/u8/7.png
#   inflating: /content/drive/MyDrive/orl_face/u8/8.png
#   inflating: /content/drive/MyDrive/orl_face/u8/9.png
#    creating: /content/drive/MyDrive/orl_face/u9/
#   inflating: /content/drive/MyDrive/orl_face/u9/1.png
#   inflating: /content/drive/MyDrive/orl_face/u9/10.png
#   inflating: /content/drive/MyDrive/orl_face/u9/2.png
#   inflating: /content/drive/MyDrive/orl_face/u9/3.png
#   inflating: /content/drive/MyDrive/orl_face/u9/4.png
#   inflating: /content/drive/MyDrive/orl_face/u9/5.png
#   inflating: /content/drive/MyDrive/orl_face/u9/6.png
#   inflating: /content/drive/MyDrive/orl_face/u9/7.png
#   inflating: /content/drive/MyDrive/orl_face/u9/8.png
#   inflating: /content/drive/MyDrive/orl_face/u9/9.png

# %%
import matplotlib.image as mimg
import matplotlib.pyplot as plt

# access any single image
usr_name = 24
samp_no = 6

path = "/gdrive/MyDrive/Colab Notebooks/orl_face/orl_face/u%d/%d.png"%(usr_name,samp_no)

# read the image
im = mimg.imread(path)

print(type(im))
print(im.shape)

# display the image
plt.imshow(im,cmap='gray')
plt.axis('off')

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mimg
# logic to access all the samples of all
# the users
tot_samples = 400
data = np.zeros((tot_samples,im.shape[0]*im.shape[1]))
label = np.zeros((tot_samples))
images = np.zeros((tot_samples,im.shape[0],im.shape[1]))
indx=-1
for i in range(1,41,1): # to traverse users
  for j in range(1,11,1): # to traverse samples
    indx = indx+1
    # access any single image
    usr_name = i
    samp_no = j
    path = "/content/drive/MyDrive/orl_face/u%d/%d.png"%(usr_name,samp_no)

    # read the image
    im = mimg.imread(path)
    feat = im.reshape(1,-1)
    data[indx,:]=feat
    label[indx]=i
    images[indx,:,:]=im
    print("user num ",i,'samp no',j,'processed...')
# Out:
# user num  1 samp no 1 processed...
# user num  1 samp no 2 processed...
# user num  1 samp no 3 processed...
# user num  1 samp no 4 processed...
# user num  1 samp no 5 processed...
# user num  1 samp no 6 processed...
# user num  1 samp no 7 processed...
# user num  1 samp no 8 processed...
# user num  1 samp no 9 processed...
# user num  1 samp no 10 processed...
# user num  2 samp no 1 processed...
# user num  2 samp no 2 processed...
# user num  2 samp no 3 processed...
# user num  2 samp no 4 processed...
# user num  2 samp no 5 processed...
# user num  2 samp no 6 processed...
# user num  2 samp no 7 processed...
# user num  2 samp no 8 processed...
# user num  2 samp no 9 processed...
# user num  2 samp no 10 processed...
# user num  3 samp no 1 processed...
# user num  3 samp no 2 processed...
# user num  3 samp no 3 processed...
# user num  3 samp no 4 processed...
# user num  3 samp no 5 processed...
# user num  3 samp no 6 processed...
# user num  3 samp no 7 processed...
# user num  3 samp no 8 processed...
# user num  3 samp no 9 processed...
# user num  3 samp no 10 processed...
# user num  4 samp no 1 processed...
# user num  4 samp no 2 processed...
# user num  4 samp no 3 processed...
# user num  4 samp no 4 processed...
# user num  4 samp no 5 processed...
# user num  4 samp no 6 processed...
# user num  4 samp no 7 processed...
# user num  4 samp no 8 processed...
# user num  4 samp no 9 processed...
# user num  4 samp no 10 processed...
# user num  5 samp no 1 processed...
# user num  5 samp no 2 processed...
# user num  5 samp no 3 processed...
# user num  5 samp no 4 processed...
# user num  5 samp no 5 processed...
# user num  5 samp no 6 processed...
# user num  5 samp no 7 processed...
# user num  5 samp no 8 processed...
# user num  5 samp no 9 processed...
# user num  5 samp no 10 processed...
# user num  6 samp no 1 processed...
# user num  6 samp no 2 processed...
# user num  6 samp no 3 processed...
# user num  6 samp no 4 processed...
# user num  6 samp no 5 processed...
# user num  6 samp no 6 processed...
# user num  6 samp no 7 processed...
# user num  6 samp no 8 processed...
# user num  6 samp no 9 processed...
# user num  6 samp no 10 processed...
# user num  7 samp no 1 processed...
# user num  7 samp no 2 processed...
# user num  7 samp no 3 processed...
# user num  7 samp no 4 processed...
# user num  7 samp no 5 processed...
# user num  7 samp no 6 processed...
# user num  7 samp no 7 processed...
# user num  7 samp no 8 processed...
# user num  7 samp no 9 processed...
# user num  7 samp no 10 processed...
# user num  8 samp no 1 processed...
# user num  8 samp no 2 processed...
# user num  8 samp no 3 processed...
# user num  8 samp no 4 processed...
# user num  8 samp no 5 processed...
# user num  8 samp no 6 processed...
# user num  8 samp no 7 processed...
# user num  8 samp no 8 processed...
# user num  8 samp no 9 processed...
# user num  8 samp no 10 processed...
# user num  9 samp no 1 processed...
# user num  9 samp no 2 processed...
# user num  9 samp no 3 processed...
# user num  9 samp no 4 processed...
# user num  9 samp no 5 processed...
# user num  9 samp no 6 processed...
# user num  9 samp no 7 processed...
# user num  9 samp no 8 processed...
# user num  9 samp no 9 processed...
# user num  9 samp no 10 processed...
# user num  10 samp no 1 processed...
# user num  10 samp no 2 processed...
# user num  10 samp no 3 processed...
# user num  10 samp no 4 processed...
# user num  10 samp no 5 processed...
# user num  10 samp no 6 processed...
# user num  10 samp no 7 processed...
# user num  10 samp no 8 processed...
# user num  10 samp no 9 processed...
# user num  10 samp no 10 processed...
# user num  11 samp no 1 processed...
# user num  11 samp no 2 processed...
# user num  11 samp no 3 processed...
# user num  11 samp no 4 processed...
# user num  11 samp no 5 processed...
# user num  11 samp no 6 processed...
# user num  11 samp no 7 processed...
# user num  11 samp no 8 processed...
# user num  11 samp no 9 processed...
# user num  11 samp no 10 processed...
# user num  12 samp no 1 processed...
# user num  12 samp no 2 processed...
# user num  12 samp no 3 processed...
# user num  12 samp no 4 processed...
# user num  12 samp no 5 processed...
# user num  12 samp no 6 processed...
# user num  12 samp no 7 processed...
# user num  12 samp no 8 processed...
# user num  12 samp no 9 processed...
# user num  12 samp no 10 processed...
# user num  13 samp no 1 processed...
# user num  13 samp no 2 processed...
# user num  13 samp no 3 processed...
# user num  13 samp no 4 processed...
# user num  13 samp no 5 processed...
# user num  13 samp no 6 processed...
# user num  13 samp no 7 processed...
# user num  13 samp no 8 processed...
# user num  13 samp no 9 processed...
# user num  13 samp no 10 processed...
# user num  14 samp no 1 processed...
# user num  14 samp no 2 processed...
# user num  14 samp no 3 processed...
# user num  14 samp no 4 processed...
# user num  14 samp no 5 processed...
# user num  14 samp no 6 processed...
# user num  14 samp no 7 processed...
# user num  14 samp no 8 processed...
# user num  14 samp no 9 processed...
# user num  14 samp no 10 processed...
# user num  15 samp no 1 processed...
# user num  15 samp no 2 processed...
# user num  15 samp no 3 processed...
# user num  15 samp no 4 processed...
# user num  15 samp no 5 processed...
# user num  15 samp no 6 processed...
# user num  15 samp no 7 processed...
# user num  15 samp no 8 processed...
# user num  15 samp no 9 processed...
# user num  15 samp no 10 processed...
# user num  16 samp no 1 processed...
# user num  16 samp no 2 processed...
# user num  16 samp no 3 processed...
# user num  16 samp no 4 processed...
# user num  16 samp no 5 processed...
# user num  16 samp no 6 processed...
# user num  16 samp no 7 processed...
# user num  16 samp no 8 processed...
# user num  16 samp no 9 processed...
# user num  16 samp no 10 processed...
# user num  17 samp no 1 processed...
# user num  17 samp no 2 processed...
# user num  17 samp no 3 processed...
# user num  17 samp no 4 processed...
# user num  17 samp no 5 processed...
# user num  17 samp no 6 processed...
# user num  17 samp no 7 processed...
# user num  17 samp no 8 processed...
# user num  17 samp no 9 processed...
# user num  17 samp no 10 processed...
# user num  18 samp no 1 processed...
# user num  18 samp no 2 processed...
# user num  18 samp no 3 processed...
# user num  18 samp no 4 processed...
# user num  18 samp no 5 processed...
# user num  18 samp no 6 processed...
# user num  18 samp no 7 processed...
# user num  18 samp no 8 processed...
# user num  18 samp no 9 processed...
# user num  18 samp no 10 processed...
# user num  19 samp no 1 processed...
# user num  19 samp no 2 processed...
# user num  19 samp no 3 processed...
# user num  19 samp no 4 processed...
# user num  19 samp no 5 processed...
# user num  19 samp no 6 processed...
# user num  19 samp no 7 processed...
# user num  19 samp no 8 processed...
# user num  19 samp no 9 processed...
# user num  19 samp no 10 processed...
# user num  20 samp no 1 processed...
# user num  20 samp no 2 processed...
# user num  20 samp no 3 processed...
# user num  20 samp no 4 processed...
# user num  20 samp no 5 processed...
# user num  20 samp no 6 processed...
# user num  20 samp no 7 processed...
# user num  20 samp no 8 processed...
# user num  20 samp no 9 processed...
# user num  20 samp no 10 processed...
# user num  21 samp no 1 processed...
# user num  21 samp no 2 processed...
# user num  21 samp no 3 processed...
# user num  21 samp no 4 processed...
# user num  21 samp no 5 processed...
# user num  21 samp no 6 processed...
# user num  21 samp no 7 processed...
# user num  21 samp no 8 processed...
# user num  21 samp no 9 processed...
# user num  21 samp no 10 processed...
# user num  22 samp no 1 processed...
# user num  22 samp no 2 processed...
# user num  22 samp no 3 processed...
# user num  22 samp no 4 processed...
# user num  22 samp no 5 processed...
# user num  22 samp no 6 processed...
# user num  22 samp no 7 processed...
# user num  22 samp no 8 processed...
# user num  22 samp no 9 processed...
# user num  22 samp no 10 processed...
# user num  23 samp no 1 processed...
# user num  23 samp no 2 processed...
# user num  23 samp no 3 processed...
# user num  23 samp no 4 processed...
# user num  23 samp no 5 processed...
# user num  23 samp no 6 processed...
# user num  23 samp no 7 processed...
# user num  23 samp no 8 processed...
# user num  23 samp no 9 processed...
# user num  23 samp no 10 processed...
# user num  24 samp no 1 processed...
# user num  24 samp no 2 processed...
# user num  24 samp no 3 processed...
# user num  24 samp no 4 processed...
# user num  24 samp no 5 processed...
# user num  24 samp no 6 processed...
# user num  24 samp no 7 processed...
# user num  24 samp no 8 processed...
# user num  24 samp no 9 processed...
# user num  24 samp no 10 processed...
# user num  25 samp no 1 processed...
# user num  25 samp no 2 processed...
# user num  25 samp no 3 processed...
# user num  25 samp no 4 processed...
# user num  25 samp no 5 processed...
# user num  25 samp no 6 processed...
# user num  25 samp no 7 processed...
# user num  25 samp no 8 processed...
# user num  25 samp no 9 processed...
# user num  25 samp no 10 processed...
# user num  26 samp no 1 processed...
# user num  26 samp no 2 processed...
# user num  26 samp no 3 processed...
# user num  26 samp no 4 processed...
# user num  26 samp no 5 processed...
# user num  26 samp no 6 processed...
# user num  26 samp no 7 processed...
# user num  26 samp no 8 processed...
# user num  26 samp no 9 processed...
# user num  26 samp no 10 processed...
# user num  27 samp no 1 processed...
# user num  27 samp no 2 processed...
# user num  27 samp no 3 processed...
# user num  27 samp no 4 processed...
# user num  27 samp no 5 processed...
# user num  27 samp no 6 processed...
# user num  27 samp no 7 processed...
# user num  27 samp no 8 processed...
# user num  27 samp no 9 processed...
# user num  27 samp no 10 processed...
# user num  28 samp no 1 processed...
# user num  28 samp no 2 processed...
# user num  28 samp no 3 processed...
# user num  28 samp no 4 processed...
# user num  28 samp no 5 processed...
# user num  28 samp no 6 processed...
# user num  28 samp no 7 processed...
# user num  28 samp no 8 processed...
# user num  28 samp no 9 processed...
# user num  28 samp no 10 processed...
# user num  29 samp no 1 processed...
# user num  29 samp no 2 processed...
# user num  29 samp no 3 processed...
# user num  29 samp no 4 processed...
# user num  29 samp no 5 processed...
# user num  29 samp no 6 processed...
# user num  29 samp no 7 processed...
# user num  29 samp no 8 processed...
# user num  29 samp no 9 processed...
# user num  29 samp no 10 processed...
# user num  30 samp no 1 processed...
# user num  30 samp no 2 processed...
# user num  30 samp no 3 processed...
# user num  30 samp no 4 processed...
# user num  30 samp no 5 processed...
# user num  30 samp no 6 processed...
# user num  30 samp no 7 processed...
# user num  30 samp no 8 processed...
# user num  30 samp no 9 processed...
# user num  30 samp no 10 processed...
# user num  31 samp no 1 processed...
# user num  31 samp no 2 processed...
# user num  31 samp no 3 processed...
# user num  31 samp no 4 processed...
# user num  31 samp no 5 processed...
# user num  31 samp no 6 processed...
# user num  31 samp no 7 processed...
# user num  31 samp no 8 processed...
# user num  31 samp no 9 processed...
# user num  31 samp no 10 processed...
# user num  32 samp no 1 processed...
# user num  32 samp no 2 processed...
# user num  32 samp no 3 processed...
# user num  32 samp no 4 processed...
# user num  32 samp no 5 processed...
# user num  32 samp no 6 processed...
# user num  32 samp no 7 processed...
# user num  32 samp no 8 processed...
# user num  32 samp no 9 processed...
# user num  32 samp no 10 processed...
# user num  33 samp no 1 processed...
# user num  33 samp no 2 processed...
# user num  33 samp no 3 processed...
# user num  33 samp no 4 processed...
# user num  33 samp no 5 processed...
# user num  33 samp no 6 processed...
# user num  33 samp no 7 processed...
# user num  33 samp no 8 processed...
# user num  33 samp no 9 processed...
# user num  33 samp no 10 processed...
# user num  34 samp no 1 processed...
# user num  34 samp no 2 processed...
# user num  34 samp no 3 processed...
# user num  34 samp no 4 processed...
# user num  34 samp no 5 processed...
# user num  34 samp no 6 processed...
# user num  34 samp no 7 processed...
# user num  34 samp no 8 processed...
# user num  34 samp no 9 processed...
# user num  34 samp no 10 processed...
# user num  35 samp no 1 processed...
# user num  35 samp no 2 processed...
# user num  35 samp no 3 processed...
# user num  35 samp no 4 processed...
# user num  35 samp no 5 processed...
# user num  35 samp no 6 processed...
# user num  35 samp no 7 processed...
# user num  35 samp no 8 processed...
# user num  35 samp no 9 processed...
# user num  35 samp no 10 processed...
# user num  36 samp no 1 processed...
# user num  36 samp no 2 processed...
# user num  36 samp no 3 processed...
# user num  36 samp no 4 processed...
# user num  36 samp no 5 processed...
# user num  36 samp no 6 processed...
# user num  36 samp no 7 processed...
# user num  36 samp no 8 processed...
# user num  36 samp no 9 processed...
# user num  36 samp no 10 processed...
# user num  37 samp no 1 processed...
# user num  37 samp no 2 processed...
# user num  37 samp no 3 processed...
# user num  37 samp no 4 processed...
# user num  37 samp no 5 processed...
# user num  37 samp no 6 processed...
# user num  37 samp no 7 processed...
# user num  37 samp no 8 processed...
# user num  37 samp no 9 processed...
# user num  37 samp no 10 processed...
# user num  38 samp no 1 processed...
# user num  38 samp no 2 processed...
# user num  38 samp no 3 processed...
# user num  38 samp no 4 processed...
# user num  38 samp no 5 processed...
# user num  38 samp no 6 processed...
# user num  38 samp no 7 processed...
# user num  38 samp no 8 processed...
# user num  38 samp no 9 processed...
# user num  38 samp no 10 processed...
# user num  39 samp no 1 processed...
# user num  39 samp no 2 processed...
# user num  39 samp no 3 processed...
# user num  39 samp no 4 processed...
# user num  39 samp no 5 processed...
# user num  39 samp no 6 processed...
# user num  39 samp no 7 processed...
# user num  39 samp no 8 processed...
# user num  39 samp no 9 processed...
# user num  39 samp no 10 processed...
# user num  40 samp no 1 processed...
# user num  40 samp no 2 processed...
# user num  40 samp no 3 processed...
# user num  40 samp no 4 processed...
# user num  40 samp no 5 processed...
# user num  40 samp no 6 processed...
# user num  40 samp no 7 processed...
# user num  40 samp no 8 processed...
# user num  40 samp no 9 processed...
# user num  40 samp no 10 processed...

# %%
# mounting the google drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# load any sample for the datset
# ask the coder , user Id and select any random 1-10 sample number of that user id
# as the query image
import matplotlib.image as mimg
import matplotlib.pyplot as plt
import numpy as np

# load the query image
usrId = int(input("Enter the user number:"))
samp = np.random.randint(8,10) # selecting any random sample number
path = "/content/drive/MyDrive/orl_face/u%d/%d.png"%(usrId,samp)

im = mimg.imread(path)

plt.figure(1,(5,5))
plt.imshow(im,cmap='gray')
plt.axis('off')
plt.title("Query image")
# Out:
# Enter the user number:12
# Text(0.5, 1.0, 'Query image')

# %%
import joblib
from sklearn import svm ,metrics
# calcualte the features of the query image
feat_query = im.reshape(1,-1)

# model path
path_model = '/content/drive/MyDrive/orl_face/orl_face.pkl'
# load the trained model
face_model = joblib.load(path_model)


# predict the id of the query image
id = face_model.predict(feat_query)
print("User id predicted is :",int(id[0]))


path = "/content/drive/MyDrive/orl_face/u%d/%d.png"%(id[0],1)

im_pred = mimg.imread(path)

plt.figure(1,(8,5))
plt.subplot(1,2,1)
plt.imshow(im,cmap='gray')
plt.axis('off')
plt.title("Query image")

plt.subplot(1,2,2)
plt.imshow(im_pred,cmap='gray')
plt.axis('off')
plt.title("predicted user")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-9c86d9f55674> in <cell line: 9>()
#       7 path_model = '/content/drive/MyDrive/orl_face/orl_face.pkl'
#       8 # load the trained model
# ----> 9 face_model = joblib.load(path_model)
#      10
#      11
#
# /usr/local/lib/python3.10/dist-packages/joblib/numpy_pickle.py in load(filename, mmap_mode)
#     648             obj = _unpickle(fobj)
#     649     else:
# --> 650         with open(filename, 'rb') as f:
#     651             with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652                 if isinstance(fobj, str):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/orl_face/orl_face.pkl'

# %%
import joblib
# final best model
# kernel function - linear , C =1

orl_svm_model = svm.SVC(kernel='linear',gamma='scale',C=1)
# train the model
orl_svm_model = orl_svm_model.fit(Xtrain,ytrain)

# save the trained model
joblib.dump(orl_svm_model,'/content/drive/MyDrive/orl_face.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b0e9ec502fc7> in <cell line: 7>()
#       5 orl_svm_model = svm.SVC(kernel='linear',gamma='scale',C=1)
#       6 # train the model
# ----> 7 orl_svm_model = orl_svm_model.fit(Xtrain,ytrain)
#       8
#       9 # save the trained model
#
# NameError: name 'Xtrain' is not defined
